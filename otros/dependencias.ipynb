# %%
import pandas as pd

# %%
import sys
# !{sys.executable} -m pip install pandas

# %%
import sys
# !{sys.executable} -m pip install openpyxl
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Out:
#    ID Casado Carro  Hijos      Casa Sexo  Sueldo  Incapacidades  Antiguedad  \
# 0   1     Sí    No      0  Alquiler    H   10000              7        15.0
# 1   2     No    Sí      1  Alquiler    M   20000              3         3.0
# 2   3     Sí    Sí      2      Prop    H   15000              5        10.0
# 3   4     Sí    Sí      1  Alquiler    M   30000             15         7.0
# 4   5     Sí    Sí      0      Prop    H   10000              1         6.0
#
#   Fuga
# 0   No
# 1   Sí
# 2   Sí
# 3   No
# 4   Sí
