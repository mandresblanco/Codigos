# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/USUARIO/Downloads/caixabank_df.csv", sep = ",")
df.to_csv("C:/Users/USUARIO/Downloads/caixabank_df_2.csv", index = False, sep = ",")

df.head()
# Out:
#    id_x  current_age  retirement_age  birth_year  birth_month  gender  \
# 0   877           36              63        1983            8  Female
# 1   877           36              63        1983            8  Female
# 2   877           36              63        1983            8  Female
# 3   877           36              63        1983            8  Female
# 4   877           36              63        1983            8  Female
#
#               address  latitude  longitude per_capita_income  ... card_id  \
# 0  801 Mill Boulevard     33.44    -111.85            $16829  ...    3877
# 1  801 Mill Boulevard     33.44    -111.85            $16829  ...    3877
# 2  801 Mill Boulevard     33.44    -111.85            $16829  ...    3877
# 3  801 Mill Boulevard     33.44    -111.85            $16829  ...    3877
# 4  801 Mill Boulevard     33.44    -111.85            $16829  ...    3877
#
#                    amount          use_chip  merchant_id  merchant_city  \
# ...
